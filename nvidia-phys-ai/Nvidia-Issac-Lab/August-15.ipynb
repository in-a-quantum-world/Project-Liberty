# %%
import numpy as np
print(np.__version__)
# Out:
# 2.5.1

# %% [markdown]
#    An ndarray is (usually fixed-size) multidimensional container of items of the
#    same type and size. The number of dimensions and items in an array is defined
#    by its shape, which is a tple of N non-negative ints that specify the size of
#    each dimension.
